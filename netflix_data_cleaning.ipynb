# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset Overview

# %%
df_netflix = pd.read_csv("netflix_titles.csv")

# %%
df_netflix.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
# data types
df_netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# shape of dataframe
df_netflix.shape
# Out:
# (8807, 12)

# %% [markdown]
# ## Missing Data Assessment

# %%
# numbeR of rows missing in each column
df_netflix.isnull().sum().sort_values(ascending=False)
# Out:
# director        2634
# country          831
# cast             825
# date_added        10
# rating             4
# duration           3
# show_id            0
# type               0
# title              0
# release_year       0
# listed_in          0
# description        0
# dtype: int64

# %%
# percentage of rows mssing in each column
for column in df_netflix.columns:
    percentage = df_netflix[column].isnull().mean()
    print(f"{column} : {round(percentage*100, 2)}%")
# Out:
# show_id : 0.0%
# type : 0.0%
# title : 0.0%
# director : 29.91%
# cast : 9.37%
# country : 9.44%
# date_added : 0.11%
# release_year : 0.0%
# rating : 0.05%
# duration : 0.03%
# listed_in : 0.0%
# description : 0.0%

# %%
# dealing with missing data

# 1: drop column
#df_netflix.drop("director", axis=1)
# 2: drop rows where director = NaN
no_director = df_netflix[df_netflix["director"].isnull()].index
df_netflix.drop(no_director, axis=0, inplace=True)

# %%
df_netflix
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
# replacing NaN by the mean, median(numeric data) or mode

df_netflix["rating"].mode()
# Out:
# 0    TV-MA
# Name: rating, dtype: object

# %%
mode = "".join(df_netflix["rating"].mode())

# %%
type(mode)
# Out:
# str

# %%
df_netflix["rating"] = df_netflix["rating"].fillna(mode)

# %%
df_netflix.isnull().mean()
# Out:
# show_id         0.000000
# type            0.000000
# title           0.000000
# director        0.000000
# cast            0.076624
# country         0.068362
# date_added      0.000000
# release_year    0.000000
# rating          0.000000
# duration        0.000486
# listed_in       0.000000
# description     0.000000
# dtype: float64

# %%
df_netflix["duration"]
# Out:
# 0         90 min
# 2       1 Season
# 5       1 Season
# 6         91 min
# 7        125 min
#           ...
# 8801      96 min
# 8802     158 min
# 8804      88 min
# 8805      88 min
# 8806     111 min
# Name: duration, Length: 6173, dtype: object

# %%
# repalcing NaN with arbitrary number
df_netflix["duration"].fillna("0", inplace=True)

# %%
# extracting data from "duration" column for movies only
df_movies = df_netflix[df_netflix["type"]=="Movie"]
df_movies["duration"]
# Out:
# 0        90 min
# 6        91 min
# 7       125 min
# 9       104 min
# 12      127 min
#          ...
# 8801     96 min
# 8802    158 min
# 8804     88 min
# 8805     88 min
# 8806    111 min
# Name: duration, Length: 5943, dtype: object

# %%
df_movies["duration"].str.split(expand=True)[0]
# Out:
# 0        90
# 6        91
# 7       125
# 9       104
# 12      127
#        ...
# 8801     96
# 8802    158
# 8804     88
# 8805     88
# 8806    111
# Name: 0, Length: 5943, dtype: object

# %%
df_movies["minute"] = df_movies["duration"].str.split(expand=True)[0].astype(int)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_119556\326785058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies["minute"] = df_movies["duration"].str.split(expand=True)[0].astype(int)

# %%
# minute columns 
df_movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
# minute columns is integer
df_movies.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# minute           int64
# dtype: object

# %%
df_movies["date_added"].str.split(",", expand=True)[1]
# Out:
# 0        2021
# 6        2021
# 7        2021
# 9        2021
# 12       2021
#         ...
# 8801     2016
# 8802     2019
# 8804     2019
# 8805     2020
# 8806     2019
# Name: 1, Length: 5943, dtype: object

# %%
# extracting only years - 4 digits
df_movies["date_added"].str.extract("(\d{4})")
# Out:
#          0
# 0     2021
# 6     2021
# 7     2021
# 9     2021
# 12    2021
# ...    ...
# 8801  2016
# 8802  2019
# 8804  2019
# 8805  2020
# 8806  2019
#
# [5943 rows x 1 columns]

# %% [markdown]
# # Identifying Outliers

# %% [markdown]
# ## Using histogram

# %%
# histogram to identify within numeric data
df_movies["minute"].plot(kind="hist", bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# bar ranges
df_movies["minute"].value_counts(bins=10).sort_index()
# Out:
# (-0.254, 25.3]      72
# (25.3, 50.6]       157
# (50.6, 75.9]       567
# (75.9, 101.2]     2475
# (101.2, 126.5]    1813
# (126.5, 151.8]     631
# (151.8, 177.1]     178
# (177.1, 202.4]      34
# (202.4, 227.7]      10
# (227.7, 253.0]       6
# Name: count, dtype: int64

# %%
# dealing with otliers
df_movies[(df_movies["minute"]>31) & (df_movies["minute"]<218)]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df_movies[~((df_movies["minute"]>31) & (df_movies["minute"]<218))]
# Out:
#      show_id   type                                              title  \
# 45       s46  Movie                             My Heroes Were Cowboys
# 71       s72  Movie                        A StoryBots Space Adventure
# 166     s167  Movie                        Once Upon a Time in America
# 694     s695  Movie                                              Aziza
# 695     s696  Movie                                     Besieged Bread
# ...      ...    ...                                                ...
# 7788   s7789  Movie  Power Rangers: Megaforce: The Robo Knight Befo...
# 7848   s7849  Movie                                            Refugee
# 7891   s7892  Movie                                  Room on the Broom
# 7932   s7933  Movie                                             Sangam
# 8205   s8206  Movie                               The Battle of Midway
#
#                              director  \
# 45                        Tyler Greco
# ...

# %% [markdown]
# ## Using boxplot

# %%
df_movies["minute"].plot(kind="box", vert=False, color="blue", figsize=(12,5))

plt.xlabel('Duration (minutes)')
plt.show()

# %%
# overview descriptive statitics
print(df_movies['minute'].describe())
# Out:
# count    5943.000000
# mean      100.533064
# std        27.399894
# min         0.000000
# 25%        88.000000
# 50%        99.000000
# 75%       115.000000
# max       253.000000
# Name: minute, dtype: float64

# %%
# IQR = Q3-Q1
min_boxplot = 87 - 1.5*(114 - 87) # Q1 - 1.5*IQR
max_boxplot = 114 + 1.5*(114 - 87) # Q3 + 1.5*IQR

print(min_boxplot)
print(max_boxplot)
# Out:
# 46.5
# 154.5

# %%
# Dealing with Outliers
df_movies[(df_movies['minute']<46.5) | (df_movies['minute']>154.5)]
# Out:
#      show_id   type                            title         director  \
# 22       s23  Movie                  Avvai Shanmughi   K.S. Ravikumar
# 24       s25  Movie                            Jeans       S. Shankar
# 45       s46  Movie           My Heroes Were Cowboys      Tyler Greco
# 71       s72  Movie      A StoryBots Space Adventure  David A. Vargas
# 73       s74  Movie                     King of Boys     Kemi Adetiba
# ...      ...    ...                              ...              ...
# 8763   s8764  Movie  WWII: Report from the Aleutians      John Huston
# 8764   s8765  Movie                       Wyatt Earp  Lawrence Kasdan
# 8770   s8771  Movie                          Yaadein     Subhash Ghai
# 8788   s8789  Movie                     You Carry Me       Ivona Juka
# 8802   s8803  Movie                           Zodiac    David Fincher
#
#                                                    cast  \
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# ...

# %% [markdown]
# ## Using bars

# %%
# using bars to identify outliers within categorical data
df_movies["rating"].value_counts()
# Out:
# rating
# TV-MA       1994
# TV-14       1393
# R            794
# TV-PG        517
# PG-13        489
# PG           286
# TV-Y7        123
# TV-G         114
# TV-Y         105
# NR            75
# G             41
# TV-Y7-FV       4
# UR             3
# NC-17          2
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df_movies["rating"].value_counts().plot(kind="bar", figsize=(12,6))
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
# # Text Normalization

# %%
# Standardize movie titles by removing extra spaces, converting to uppercase,
# removing punctuation for more consistent text analysis.
import re

df_movie = df_netflix[df_netflix["type"] == "Movie"].copy()
df_movie["title_original"] = df_movie["title"]

def normalize_title(title):
    if pd.isna(title):
        return title
    title = title.strip()
    title = title.upper()
    title = re.sub(r"[^\w\s]", "", title)
    title = re.sub(r"\s+", " ", title)
    return title

df_movie["title_clean"] = df_movie["title"].apply(normalize_title)

title_changes = df_movie.loc[
    df_movie["title_original"] != df_movie["title_clean"],
    ["title_original", "title_clean"]
]

print("Sample of cleaned titles:")
print(title_changes.head(10))

print(f"\nTotal cleaned titles: {len(title_changes)}")
# Out:
# Sample of cleaned titles:
#                                        title_original  \
# 0                                Dick Johnson Is Dead
# 6                    My Little Pony: A New Generation
# 7                                             Sankofa
# 9                                        The Starling
# 12                                       Je Suis Karl
# 13                   Confessions of an Invisible Girl
# 16  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 18                                          Intrusion
# 22                                    Avvai Shanmughi
# 23       Go! Go! Cory Carson: Chrissy Takes the Wheel
#
#                                           title_clean
# 0                                DICK JOHNSON IS DEAD
# 6                     MY LITTLE PONY A NEW GENERATION
# 7                                             SANKOFA
# 9                                        THE STARLING
# 12                                       JE SUIS KARL
# ...

# %% [markdown]
# ## Key Findings
#
# - The `director` column contains the highest percentage of missing values.
# - `country` and `cast` also have notable missing data.
# - A few records appear to have misaligned values between `rating` and `duration`.
# - Movie durations are mostly concentrated between roughly 80 and 120 minutes.
# - Title normalization improves consistency for text-based analysis.

# %%
df_movie.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...
